# %% [markdown]
# # Jupyter Notebooks
# **Jupyter** notebooks are commonly used to combine Markdown and Python into a single file. For example, this file is a notebook file! Imagine a blog post where you can talk about your thought process, show your code, and also let readers run the code.
#
# The great things about cells is that you can run specific sections of code at a time. You can also quickly see the return values of each cell without running the entire file.

# %%
# Try running this cell!
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# # Pandas

# %% [markdown]
# 1. What happens when you run the code below? Make sure you change the path to point to where `penguins.csv` is stored on your own computer.

# %%
# We're going to work with a new library called pandas
import pandas as pd

penguins = pd.read_csv("../Datasets/penguins.csv")
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 337  Chinstrap      Dream            55.8           19.8                207
# 338  Chinstrap      Dream            43.5           18.1                202
# 339  Chinstrap      Dream            49.6           18.2                193
# 340  Chinstrap      Dream            50.8           19.0                210
# 341  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex  year
# 0           3750    male  2007
# 1           3800  female  2007
# 2           3250  female  2007
# 3           3450  female  2007
# 4           3650    male  2007
# ..           ...     ...   ...
# 337         4000    male  2009
# 338         3400  female  2009
# 339         3775    male  2009
# 340         4100    male  2009
# 341         3775  female  2009
#
# [342 rows x 8 columns]

# %% [markdown]
# 2. What happens when you run the code below? Add a cell block to access the column for species.

# %%
penguins[["bill_length_mm", "species"]]
# Out:
#      bill_length_mm    species
# 0              39.1     Adelie
# 1              39.5     Adelie
# 2              40.3     Adelie
# 3              36.7     Adelie
# 4              39.3     Adelie
# ..              ...        ...
# 337            55.8  Chinstrap
# 338            43.5  Chinstrap
# 339            49.6  Chinstrap
# 340            50.8  Chinstrap
# 341            50.2  Chinstrap
#
# [342 rows x 2 columns]

# %%
penguins[penguins["species"] == "Adelie"]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 146  Adelie      Dream            36.6           18.4              184.0
# 147  Adelie      Dream            36.0           17.8              195.0
# 148  Adelie      Dream            37.8           18.1              193.0
# 149  Adelie      Dream            36.0           17.1              187.0
# 150  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3         3450.0  female  2007
# 4         3650.0    male  2007
# ..           ...     ...   ...
# 146       3475.0  female  2009
# 147       3450.0  female  2009
# 148       3750.0    male  2009
# 149       3700.0  female  2009
# 150       4000.0    male  2009
#
# [151 rows x 8 columns]

# %% [markdown]
# 3. What happens when you run the code below? Add a cell block to list all Adelie penguins.

# %%
penguins[penguins["species"] =="Adelie"]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7                181
# 1    Adelie  Torgersen            39.5           17.4                186
# 2    Adelie  Torgersen            40.3           18.0                195
# 3    Adelie  Torgersen            36.7           19.3                193
# 4    Adelie  Torgersen            39.3           20.6                190
# ..      ...        ...             ...            ...                ...
# 146  Adelie      Dream            36.6           18.4                184
# 147  Adelie      Dream            36.0           17.8                195
# 148  Adelie      Dream            37.8           18.1                193
# 149  Adelie      Dream            36.0           17.1                187
# 150  Adelie      Dream            41.5           18.5                201
#
#      body_mass_g     sex  year
# 0           3750    male  2007
# 1           3800  female  2007
# 2           3250  female  2007
# 3           3450  female  2007
# 4           3650    male  2007
# ..           ...     ...   ...
# 146         3475  female  2009
# 147         3450  female  2009
# 148         3750    male  2009
# 149         3700  female  2009
# 150         4000    male  2009
#
# [151 rows x 8 columns]

# %%
penguins[penguins["species"] =="Gentoo"]["bill_length_mm"].std()
# Out:
# 3.081857372114287

# %%
range = penguins[penguins["species"] =="Gentoo"]["bill_length_mm"].max() - penguins[penguins["species"] =="Gentoo"]["bill_length_mm"].min()
print(range)
#when we add 80.2 to the dataset
# Out:
# 39.300000000000004

# %%
penguins[penguins["species"] =="Gentoo"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14356/506188058.py in <module>
# ----> 1 penguins[penguins["species"] =="Gentoo"]
#
# NameError: name 'penguins' is not defined

# %%
penguins[penguins["species"] =="Gentoo"]["bill_length_mm"]

# %% [markdown]
# You have been working with the **Dataframe** class that is provided by the `pandas` module! As you can see, Dataframes allow you to quickly store and access tabular information.
#
# 4. Add a cell block that _describes_ the flipper length of all penguins.

# %%
import matplotlib
penguins.hist("flipper_length_mm")
# Out:
# array([[<AxesSubplot:title={'center':'flipper_length_mm'}>]], dtype=object)
