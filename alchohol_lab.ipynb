# %%
import pandas as pd
import altair as alt
import seaborn as sns
from vega_datasets import data
df = pd.read_csv("Datasets/alch.csv")

countries = alt.topo_feature(data.world_110m.url, 'countries')

map1 = alt.Chart(countries).mark_geoshape().encode(
  color='HappinessScore:Q',
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df, 'id', ['HappinessScore'])
).project(
    "naturalEarth1"
).properties(
    width=1000,
    height=700,
    title="Map of world's happiest countries"
)

map2 = alt.Chart(countries).mark_geoshape(
    fill='lightgray',
    stroke='white'
).project(
    "naturalEarth1"
).properties(
    width=700,
    height=500
)

map3 = map2 + map1

map3
# Out:
# alt.LayerChart(...)

# %%
countries = alt.topo_feature(data.world_110m.url, 'countries')

map1 = alt.Chart(countries).mark_geoshape().encode(
  color='Wine_PerCapita:Q',
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df, 'id', ['Wine_PerCapita'])
).project(
    "naturalEarth1"
).properties(
    width=1000,
    height=700,
    title="Wine per Country"
)

map2 = alt.Chart(countries).mark_geoshape(
    fill='lightgray',
    stroke='white'
).project(
    "naturalEarth1"
).properties(
    width=700,
    height=500
)

map3 = map2 + map1

map3
# Out:
# alt.LayerChart(...)

# %%
countries = alt.topo_feature(data.world_110m.url, 'countries')

map1 = alt.Chart(countries).mark_geoshape().encode(
  color='Beer_PerCapita:Q',
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df, 'id', ['Beer_PerCapita'])
).project(
    "naturalEarth1"
).properties(
    width=1000,
    height=700,
    title="Beer per Country"
)

map2 = alt.Chart(countries).mark_geoshape(
    fill='lightgray',
    stroke='white'
).project(
    "naturalEarth1"
).properties(
    width=700,
    height=500
)

map3 = map2 + map1

map3
# Out:
# alt.LayerChart(...)

# %%
countries = alt.topo_feature(data.world_110m.url, 'countries')

map1 = alt.Chart(countries).mark_geoshape().encode(
  color='Spirit_PerCapita:Q',
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df, 'id', ['Spirit_PerCapita'])
).project(
    "naturalEarth1"
).properties(
    width=1000,
    height=700,
    title="Spirit per Country"
)

map2 = alt.Chart(countries).mark_geoshape(
    fill='lightgray',
    stroke='white'
).project(
    "naturalEarth1"
).properties(
    width=700,
    height=500
)

map3 = map2 + map1

map3
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
import altair as alt
import seaborn as sns
from vega_datasets import data
df = pd.read_csv("Datasets/student-mat.csv")


alt.Chart(df).mark_boxplot(extent='min-max').encode(
    x='Dalc:Q',
    y='G3:Q'
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_boxplot(extent='min-max').encode(
    x='Dalc:Q',
    y='studytime:Q'
).interactive()
# Out:
# alt.Chart(...)

# %%
df[["Dalc", "G3"]].corr()
# Out:
#          Dalc       G3
# Dalc  1.00000 -0.05466
# G3   -0.05466  1.00000

# %%
df[["Dalc", "studytime"]].corr()
# Out:
#                Dalc  studytime
# Dalc       1.000000  -0.196019
# studytime -0.196019   1.000000
